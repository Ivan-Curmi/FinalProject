# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
online_retail = pd.read_excel(
    "https://raw.githubusercontent.com/Ivan-Curmi/FinalProject/main/Online%20Retail.xlsx",)

# %%
df= online_retail

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.nlargest(10,"Quantity")
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 540421    581483     23843          PAPER CRAFT , LITTLE BIRDIE     80995
# 61619     541431     23166       MEDIUM CERAMIC TOP STORAGE JAR     74215
# 502122    578841     84826       ASSTD DESIGN 3D PAPER STICKERS     12540
# 74614     542504     37413                                  NaN      5568
# 421632    573008     84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS      4800
# 206121    554868     22197                 SMALL POPCORN HOLDER      4300
# 220843    556231    85123A                                    ?      4000
# 97432     544612     22053                EMPIRE DESIGN ROSETTE      3906
# 270885    560599     18007  ESSENTIAL BALM 3.5g TIN IN ENVELOPE      3186
# 52711     540815     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 540421 2011-12-09 09:15:00       2.08     16446.0  United Kingdom
# ...

# %%
df.nsmallest(10,"Quantity")
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 540422   C581484     23843          PAPER CRAFT , LITTLE BIRDIE    -80995
# 61624    C541433     23166       MEDIUM CERAMIC TOP STORAGE JAR    -74215
# 225529    556690     23005         printing smudges/thrown away     -9600
# 225530    556691     23005         printing smudges/thrown away     -9600
# 4287     C536757     84347  ROTATING SILVER ANGELS T-LIGHT HLDR     -9360
# 225528    556687     23003         Printing smudges/thrown away     -9058
# 115818    546152    72140F                           throw away     -5368
# 431381    573596    79323W               Unsaleable, destroyed.     -4830
# 341601    566768     16045                                  NaN     -3667
# 323458    565304     16259                                  NaN     -3167
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 540422 2011-12-09 09:27:00       2.08     16446.0  United Kingdom
# ...

# %%
df.nsmallest(10,"Quantity")
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 540422   C581484     23843          PAPER CRAFT , LITTLE BIRDIE    -80995
# 61624    C541433     23166       MEDIUM CERAMIC TOP STORAGE JAR    -74215
# 225529    556690     23005         printing smudges/thrown away     -9600
# 225530    556691     23005         printing smudges/thrown away     -9600
# 4287     C536757     84347  ROTATING SILVER ANGELS T-LIGHT HLDR     -9360
# 225528    556687     23003         Printing smudges/thrown away     -9058
# 115818    546152    72140F                           throw away     -5368
# 431381    573596    79323W               Unsaleable, destroyed.     -4830
# 341601    566768     16045                                  NaN     -3667
# 323458    565304     16259                                  NaN     -3167
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 540422 2011-12-09 09:27:00       2.08     16446.0  United Kingdom
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    406829 non-null  object
#  1   StockCode    406829 non-null  object
#  2   Description  406829 non-null  object
#  3   Quantity     406829 non-null  int64
#  4   InvoiceDate  406829 non-null  datetime64[ns]
#  5   UnitPrice    406829 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      406829 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.9+ MB

# %%
# Calculate total revenue and add it as a new column
df['total_revenue'] = df['Quantity'] * df['UnitPrice']

# Display the DataFrame with the new 'total_revenue' column
df.head()
# Out:
# C:\Users\ivanc\AppData\Local\Temp\ipykernel_20612\2924739929.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_revenue'] = df['Quantity'] * df['UnitPrice']
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  total_revenue
# ...

# %%
# Define your categories or keywords
categories = {
    " Decor": ["T-LIGHT HOLDER", "LANTERN", "HEARTS COAT HANGER", "WALL DECOR", "CANDLEHOLDER", "CUSHION COVER", "VASE", "PHOTO FRAME","christmas", "ceramic",  "ornament", "frame",  "knob",  "clock"],
    "Kitchenware": ["KNIFE", "CUTTING BOARD", "POT", "UTENSIL HOLDER", "COOKWARE SET", "MEASURING SPOON", "MIXING BOWL", "KITCHEN TOWEL","cuttlery" , "mug" , "cake" , "cup" , "saucer" , "jug" , "beakers" , "jar"],
    "Clothing": ["T-SHIRT", "DRESS", "PANTS", "JACKET", "JACKET", "HAT", "SCARF", "SHOES", "SOCKS"],
    "Electronics": ["SMARTPHONE", "LAPTOP", "HEADPHONES", "CHARGER", "SPEAKERS", "SMARTWATCH", "CAMERA", "TELEVISION"],
    "Beauty and Personal Care": ["SHAMPOO", "LOTION", "MAKEUP BRUSH", "NAIL POLISH", "RAZOR", "PERFUME", "HAIRDRYER", "FACE MASK"],
    "Toys and Games": ["PUZZLE", "BOARD GAME", "ACTION FIGURE", "PLAYSET", "LEGO SET", "STUFFED ANIMAL", "OUTDOOR TOYS", "RC CAR"],
    "Stationery": ["NOTEBOOK", "PENS", "STICKY NOTES", "SCISSORS", "MARKERS", "FILE FOLDERS", "BINDERS", "STAMP SET","pencils" , "postage" , "blocks" , "paper"],
    "Sports and Fitness": ["YOGA MAT", "DUMBBELLS", "JUMP ROPE", "EXERCISE BALL", "SPORTS BOTTLE", "ATHLETIC SHOES", "FITNESS TRACKER", "SPORTS BRACELET"]
}

# Convert the "Description" to strings
df["Description"] = df["Description"].astype(str)

# Create an empty column for the category
df["category"] = ""

# Iterate each row
for index, row in df.iterrows():
    description = row["Description"]
    # Iterate over each category and check for matches
    for category, keywords in categories.items():
        for keyword in keywords:
            # Check for keyword match in the description
            if keyword in description:
                # Assign the category to the corresponding row
                df.loc[index, "category"] = category  # Use .loc instead of .at
                break  # Once a match is found, stop checking keywords
    # If no match is found, you can assign a default category or leave it blank

# Save the updated DataFrame to a new CSV file
#df_new.to_csv("updated_dataset.csv", index=False)
# Out:
# C:\Users\ivanc\AppData\Local\Temp\ipykernel_29836\2895784096.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Description"] = df["Description"].astype(str)
# C:\Users\ivanc\AppData\Local\Temp\ipykernel_29836\2895784096.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["category"] = ""

# %%
import pandas as pd
import nltk
nltk.download("stopwords")
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from collections import Counter
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ivanc\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ivanc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Sample DataFrame
data = {'Description': ['This is a red apple.',
                        'A green pear.', 'Bananas are yellow.']}
df = pd.DataFrame(data)

# %%
# Preprocessing
stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()


def preprocess_text(text):
    words = nltk.word_tokenize(text.lower())
    words = [stemmer.stem(word)
             for word in words if word.isalpha() and word not in stop_words]
    return words

# %%
#2 nd trial

# Preprocessing
stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()


def preprocess_text(text):
    # Check if text is a string, and if not, return an empty list
    if not isinstance(text, str):
        return []

    words = nltk.word_tokenize(text.lower())
    words = [stemmer.stem(word)
             for word in words if word.isalpha() and word not in stop_words]
    return words


# Frequency Analysis
all_words = []
for desc in df['Description']:
    words = preprocess_text(desc)
    all_words.extend(words)

word_freq = Counter(all_words)

# Keyword Selection (top 5 keywords)
top_keywords = [word for word, freq in word_freq.most_common(15)]

print(top_keywords)
# Out:
# ['set', 'bag', 'heart', 'red', 'retrospot', 'vintag', 'design', 'box', 'pink', 'christma', 'cake', 'white', 'metal', 'jumbo', 'lunch']

# %%
top_keywords
# Out:
# ['set',
#  'bag',
#  'heart',
#  'red',
#  'retrospot',
#  'vintag',
#  'design',
#  'box',
#  'pink',
#  'christma',
#  'cake',
#  'white',
#  'metal',
#  'jumbo',
#  'lunch']

# %%
# Categorization (example mapping)
category_keywords = {
    'Decor': ['hang', 'holder', 'design', 'metal', 'ceramic', 'ornament', 'lantern', 'frame', 'knob', 'clock',  'LIGHT',  'HANGER', 'doiley',  'WALL DECOR',  'CANDLEHOLDER', 'CUSHION', 'VASE', 'quilt', 'ballons', 'doormat', 'CANDLE', 'CHRISTMAS', 'RACK', 'ALUMINIUM', 'STAR', 'KEY FOB', 'DRAWER', 'MAT', 'WICKER', 'SHELF', 'CABINET', 'STOOL', 'SPACE OWL', 'MIRROR', 'HOOK', 'INCENSE', 'DOORSTOP', 'EASTER', 'DECORATIONS', 'BABUSHKA', 'DOORSIGN', 'FLYING DUCKS', 'ART', 'PHOTO CUBE','SIGN'],
    'Stationery': ['paper', 'postage', 'pencil', 'Craft', 'pen', 'pencils', 'postage', 'blocks',  'paper', 'NOTEBOOK', 'PENS', 'erasers', 'STICKY NOTES', 'SCISSOR',  'MARKERS', 'FILE FOLDERS', 'BINDERS', 'STAMP SET', 'book', 'ribbon', 'LETTER ', 'STATIONERY', 'WRAP', 'CHALKBOARD', 'ruler', ' ORGANISER', 'WRITING'],
    'Kitchenware': ['cake', 'case', 'bottle', 'cutlery',   'mug', 'cake', 'cup', 'saucer', 'jug', 'beakers',  'bottle', 'plate', 'jar', 'KNIFE', 'CUTTING BOARD', 'diner', 'cookie', 'doilies', 'matches', 'bag', 'pannetone',  'apron',  'glass', 'POT',  'UTENSIL', 'COOKWARE SET',  'SPOON', 'BOWL',  'KITCHEN TOWEL',  'moulds',  'placemats',  'popcorn', 'HERB', 'CHOPPING BOARD', 'MOULD', 'TEA', 'SALT AND PEPPER', 'KITCHEN SCALES', 'SNACK', 'NAPKIN', 'EGG', ' FILLER PAD', 'WASHING', 'STRAWS', 'TISSUES', 'dish', 'WREATH', 'PARASOL', 'BUBBLES', 'BREAKFAST', 'JAM', 'FRYING PAN', 'KNICK KNACK', 'TRAY', 'TIN', 'BUNNIES'],
    'Toys and Games': ['game', 'lunch box', 'toys', 'puzzles', 'ACTION FIGURE', 'PLAYSET', 'LEGO SET', 'STUFFED ANIMAL', 'marbels', 'card', 'drawing', 'calculator', 'RC CAR', 'dominoes', 'party invites', 'tattoos', 'BIRTHDAY', 'HARMONICA', 'PARTY', 'BLOCK', ' PAINT', 'LUNCH BAG', 'PLAYHOUSE', 'CROQUET', 'BALLOON', 'SANDCASTLE', 'SNAKES & LADDERS', 'SKIPPING ROPE', 'STICKER', 'CHALK', 'SKITTLES', 'SPEAKER', 'BEAKER', 'BUBBLEGUM', 'TREASURE', 'SPACEBOY', 'INFLATABLE', 'CIRCUS', 'BICYCLE', 'SOFT TOY', 'BLACKBOARD', 'CIRCULAR', 'POLKADOT', 'BLACK BOARD', 'COLOURING', 'COASTER', 'BADGES'],
    'Clothing': ['T-SHIRT', 'DRESS', 'PANTS', 'JACKET' , 'HAT' , 'SCARF' , 'SHOES' , 'SOCKS'],
    'Beauty and Personal Care': ['SHAMPOO',  'LOTION', 'MAKEUP BRUSH', 'NAIL POLISH', 'TISSUE BOX', 'plaster', 'RAZOR',  'PERFUME', 'bath', 'HAIRDRYER', 'hand warmer', 'FACE MASK', 'gloss', 'JEWELLERY ', 'SEWING', 'HEART', 'FAN', 'PURSE', 'BRACELET', 'CREAM'],
    'Gardening': ['pitch', 'fork', 'GARDEN', 'PLANTER', 'WATERING ', 'GROW YOUR OWN FLOWERS'],
    'CARRIAGE': ['CARRIAGE'], 
    'Others': ['SWAT', 'CAT FOOD', 'FLYTRAP', ' STORAGE', 'TRADITIONAL NAUGHTS & CROSSES', ' PAD', 'BICYCLE BELL', 'BUTTON', 'PEG', ' TAG', 'MAGNET', 'BACKPACK', 'PASSPORT COVER', 'TOOL SET', 'JUMBO SHOPPER', 'KNITTING', 'BELLS', 'PHOTO CLIP', 'TOAST ITS', 'KEEPSAKE', 'CROCHET', ' DISCO', 'CURTAIN', ''],
    'Discount':['Discount'],
    'Manual':['Manual'],
    'Bank Charges':['Bank Charges'],

}

# %%
# Assuming you have a DataFrame 'df' with a 'Category' column

# Filter the DataFrame to get all items with 'None' category
uncategorized_items = df[df['Category'].isna() | (df['Category'] == 'None')]

# Print or use the 'uncategorized_items' DataFrame as needed
print(uncategorized_items)
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, total_revenue, Category]
# Index: []

# %%
def classify_description(desc):
    if not isinstance(desc, str):
        return None  # or a default category if desired for non-string values

    keyword_matches = {category: sum(1 for keyword in keywords if keyword.upper() in desc)
                       for category, keywords in category_keywords.items()}
    if list(keyword_matches.values()) != [0,]*len(keyword_matches):
        return max(keyword_matches, key=keyword_matches.get)
    else:
        return None
    #return max(keyword_matches, key=keyword_matches.get)


df['Category'] = df['Description'].apply(classify_description)
print(df)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
df.sample(10)
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 339575    566600     23298                      SPOTTY BUNTING         6
# 409729    572069     23310             BUBBLEGUM RING ASSORTED        36
# 97513     544638     22090             PAPER BUNTING RETROSPOT         6
# 116514    546251     20723            STRAWBERRY CHARLOTTE BAG       100
# 142971    548659     22727           ALARM CLOCK BAKELIKE RED          4
# 250079    558996     23242          TREASURE TIN BUFFALO BILL          6
# 133357    547785     20941                         FROG CANDLE         2
# 299136    563090     22904           CALENDAR PAPER CUT DESIGN         6
# 385537    570208     23264  SET OF 3 WOODEN SLEIGH DECORATIONS         4
# 77863     542789     21122  SET/10 PINK POLKADOT PARTY CANDLES        24
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
#
df.loc[df["Description"].str.contains(
    "^ .{0, 7}Cookware | Frying Pan | Saucepan | Stockpot | Dutch Oven | Wok | Roasting Pan | Grill Pan|Bakeware | Baking Sheets | Cake Pans | Muffin Tins | Bread Pans | Pie Plates | Cookie Cutters | Rolling Pin|Utensils | Chef's Knife | Paring Knife Cutting Board | Kitchen Shears | Wooden Spoons | Silicone Spatula | Tongs | Whisk | Ladle | Slotted Spoon|Small Appliances | Blender | Food Processor | Toaster | Microwave | Coffee Maker | Kettle | Stand Mixer | Hand Mixer|Storage Containers | Food Storage Containers | Plastic Wrap | Aluminum Foil | Ziplock Bags|Dinnerware and Flatware | Plates | Bowls | Glasses | Forks | Knives | Spoons|Drinkware | Mugs | Water Glasses | Wine Glasses | Coffee Cups | Teacups|Kitchen Gadgets | Can Opener | Peeler | Grater | Garlic Press | Colander | Meat Thermometer|Mixing and Measuring | Mixing Bowls | Measuring Cups and Spoons | Kitchen Scale|Cutting and Chopping | Cutting Boards | Mandoline Slicer | Herb Scissors | Salad Spinner|Kitchen Linens | Dish Towels | Dishcloths | Oven Mitts | Pot Holders | Apron|Food Prep and Serving | Mixing Bowls | Salad Bowl | Serving Platters | Serving Utensils|Specialty Items | Pasta Maker | Rice Cooker | Slow Cooker | Bread Machine | Pressure Cooker|Miscellaneous | Trash Can | Recycling Bin | Food Waste Compost Bin | cuttlery | mug | cake | cup | saucer | jug | beakers | bottle | plate | jar | KNIFE | CUTTING BOARD | diner | cookie | doilies | matches | bag | pannetone | apron | glass | POT | UTENSIL | COOKWARE SET | SPOON | BOWL | KITCHEN TOWEL | moulds | placemats | popcorn", case=False), "category"] += "Kitchenware"
df.loc[df["Description"].str.contains(
    "^.{0,7}SMARTPHONE|LAPTOP|HEADPHONES|CHARGER|SPEAKERS|SMARTWATCH|CAMERA|TELEVISION", case=False), "category"] += "Electronics"
df.loc[df["Description"].str.contains(
    "^.{0,7}SHAMPOO|LOTION|MAKEUP BRUSH|NAIL POLISH|TISSUE BOX|plaster|RAZOR|PERFUME|bath|HAIRDRYER|hand warmer|FACE MASK|gloss", case=False), "category"] += "Beauty and Personal Care"
df.loc[df["Description"].str.contains(
    "^.{0,7}pitch|fork", case=False), "category"] += "Gardening"
# Out:
# C:\Users\ivanc\AppData\Local\Temp\ipykernel_29836\3389869506.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["category"] = ""

# %%
df.sample(50)
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 281655    561584     22149          FELTCRAFT 6 FLOWER FRIENDS         6
# 186030    552843     22692         DOORMAT WELCOME TO OUR HOME         1
# 190475    553194     23049           RECYCLED ACAPULCO MAT RED         2
# 69852     541987     22480        RED TEA TOWEL CLASSIC DESIGN         3
# 330893    565930     23242          TREASURE TIN BUFFALO BILL          6
# 479652    577174    71406C               BLACK ORANGE SQUEEZER         6
# 174365    551811     21930            JUMBO STORAGE BAG SKULLS        10
# 30173     538850     21915              RED  HARMONICA IN BOX         12
# 301230    563248     21976      PACK OF 60 MUSHROOM CAKE CASES         3
# 375289    569457     21094       SET/6 RED SPOTTY PAPER PLATES         1
# 235096    557625     21365             MIRRORED WALL ART STARS        12
# 161790    550488     21179             NO JUNK MAIL METAL SIGN         7
# ...

# %%
# Calculate total sales Revenue
total_sales = df['total_revenue'].sum()
print(f'Total Sales: {total_sales}')


# Calculate average daily sales Revenue
average_daily_sales = df['total_revenue'].mean()
print(f'Average Daily Sales: {average_daily_sales}')
# Out:
# Total Sales: 8300065.814000001
# Average Daily Sales: 20.401853884555923

# %%
# Group by 'Country' and calculate total sales
total_sales_per_country = df.groupby('Country')['total_revenue'].sum().reset_index()

# Display the total sales per country
print(total_sales_per_country)
# Out:
#                  Country  total_revenue
# 0              Australia     137077.270
# 1                Austria      10154.320
# 2                Bahrain        548.400
# 3                Belgium      40910.960
# 4                 Brazil       1143.600
# 5                 Canada       3666.380
# 6        Channel Islands      20086.290
# 7                 Cyprus      12946.290
# 8         Czech Republic        707.720
# 9                Denmark      18768.140
# 10                  EIRE     250285.220
# 11    European Community       1291.750
# 12               Finland      22326.740
# 13                France     196712.840
# 14               Germany     221698.210
# 15                Greece       4710.520
# 16               Iceland       4310.000
# 17                Israel       6994.250
# 18                 Italy      16890.510
# 19                 Japan      35340.620
# 20               Lebanon       1693.880
# 21             Lithuania       1661.060
# ...

# %%
# Group by 'Customer' and calculate total sales revenue per Customer
total_sales_per_customer = df.groupby(
    'CustomerID')['total_revenue'].sum().reset_index()

# Display the total sales revenue per customer
print(total_sales_per_customer)
# Out:
#       CustomerID  total_revenue
# 0        12346.0           0.00
# 1        12347.0        4310.00
# 2        12348.0        1797.24
# 3        12349.0        1757.55
# 4        12350.0         334.40
# ...          ...            ...
# 4367     18280.0         180.60
# 4368     18281.0          80.82
# 4369     18282.0         176.60
# 4370     18283.0        2094.88
# 4371     18287.0        1837.28
#
# [4372 rows x 2 columns]

# %%
# Group by 'Country' and 'Customer' and calculate total sales revenue
total_sales_per_customer = df.groupby(['Country', 'CustomerID'])[
    'total_revenue'].sum().reset_index()

# Display the total sales revenuew per customer with country
print(total_sales_per_customer)
# Out:
#              Country  CustomerID  total_revenue
# 0          Australia     12386.0         401.90
# 1          Australia     12388.0        2780.66
# 2          Australia     12393.0        1582.60
# 3          Australia     12415.0      123725.45
# 4          Australia     12422.0         386.20
# ...              ...         ...            ...
# 4375  United Kingdom     18287.0        1837.28
# 4376     Unspecified     12363.0         552.00
# 4377     Unspecified     12743.0         546.43
# 4378     Unspecified     14265.0         530.18
# 4379     Unspecified     16320.0        1038.46
#
# [4380 rows x 3 columns]

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  total_revenue  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom          15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom          20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom          22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom          20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom          20.34
#
#             category
# 0              Decor
# 1              Decor
# 2   DecorKitchenware
# ...

# %%
# Calculate total sales Volume
total_sales = df['Quantity'].sum()
print(f'Total Sales: {total_sales}')


# Calculate average daily sales
average_daily_sales = df['Quantity'].mean()
print(f'Average Daily Sales: {average_daily_sales}')
# Out:
# Total Sales: 4906888
# Average Daily Sales: 12.06130339774205

# %%
# Group by 'Country' and calculate total sales volume
total_sales_per_country = df.groupby(
    'Country')['Quantity'].sum().reset_index()

# Display the total sales volume per country
print(total_sales_per_country)
# Out:
#                  Country  Quantity
# 0              Australia     83653
# 1                Austria      4827
# 2                Bahrain       260
# 3                Belgium     23152
# 4                 Brazil       356
# 5                 Canada      2763
# 6        Channel Islands      9479
# 7                 Cyprus      6317
# 8         Czech Republic       592
# 9                Denmark      8188
# 10                  EIRE    136329
# 11    European Community       497
# 12               Finland     10666
# 13                France    109848
# 14               Germany    117448
# 15                Greece      1556
# 16               Iceland      2458
# 17                Israel      3990
# 18                 Italy      7999
# 19                 Japan     25218
# 20               Lebanon       386
# 21             Lithuania       652
# 22                 Malta       944
# 23           Netherlands    200128
# 24                Norway     19247
# 25                Poland      3653
# ...

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  total_revenue  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom          15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom          20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom          22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom          20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom          20.34
#
#             category
# 0              Decor
# 1              Decor
# 2   DecorKitchenware
# ...

# %%
# Group by 'Customer' and calculate total sales volume per Customer 
total_sales_per_customer = df.groupby(
    'CustomerID')['Quantity'].sum().reset_index()

# Display the total sales volume per customer
print(total_sales_per_customer)
# Out:
#       CustomerID  Quantity
# 0        12346.0         0
# 1        12347.0      2458
# 2        12348.0      2341
# 3        12349.0       631
# 4        12350.0       197
# ...          ...       ...
# 4367     18280.0        45
# 4368     18281.0        54
# 4369     18282.0        98
# 4370     18283.0      1397
# 4371     18287.0      1586
#
# [4372 rows x 2 columns]

# %%
# Group by 'Customer' and calculate total sales volume per Customer 
total_sales_per_customer = df.groupby(
    'CustomerID')['Quantity'].count().reset_index()

# Display the total sales volume per customer
print(total_sales_per_customer)
# Out:
#       CustomerID  Quantity
# 0        12346.0         2
# 1        12347.0       182
# 2        12348.0        31
# 3        12349.0        73
# 4        12350.0        17
# ...          ...       ...
# 4367     18280.0        10
# 4368     18281.0         7
# 4369     18282.0        13
# 4370     18283.0       756
# 4371     18287.0        70
#
# [4372 rows x 2 columns]

# %%
df.head(
    
)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  total_revenue  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom          15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom          20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom          22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom          20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom          20.34
#
#             category
# 0              Decor
# 1              Decor
# 2   DecorKitchenware
# ...

# %%
# Group by 'Country' and 'Customer' and calculate total sales Volume
total_sales_per_customer = df.groupby(['Country', 'CustomerID'])[
    'Quantity'].sum().reset_index()

# Display the total sales Volume per customer with country
print(total_sales_per_customer)
# Out:
#              Country  CustomerID  Quantity
# 0          Australia     12386.0       354
# 1          Australia     12388.0      1462
# 2          Australia     12393.0       816
# 3          Australia     12415.0     77242
# 4          Australia     12422.0       195
# ...              ...         ...       ...
# 4375  United Kingdom     18287.0      1586
# 4376     Unspecified     12363.0       408
# 4377     Unspecified     12743.0       319
# 4378     Unspecified     14265.0       330
# 4379     Unspecified     16320.0       732
#
# [4380 rows x 3 columns]

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  total_revenue  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom          15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom          20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom          22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom          20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom          20.34
#
#       Category
# 0        Decor
# 1        Decor
# 2        Decor
# 3  Kitchenware
# ...

# %%
# Plot sales volume over time
plt.figure(figsize=(6, 4))
plt.plot(df['InvoiceDate'], df['Quantity'], marker='o', linestyle='-')
plt.title('Sales Volume Over Time')
plt.xlabel('Date')
plt.ylabel('Sales Volume')
plt.grid(True)
plt.show()

# %%
# Plot sales volume over time
plt.figure(figsize=(6, 4))
plt.plot(df['InvoiceDate'], df['total_revenue'], marker='o', linestyle='-')
plt.title('Sales Revenue Over Time')
plt.xlabel('Date')
plt.ylabel('Sales Revenue')
plt.grid(True)
plt.show()

# %%
online_retail_filter = online_retail[online_retail['Quantity'] < 0]
online_retail_filter
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
online_retail_filter = online_retail[online_retail['UnitPrice'] < 0]
online_retail_filter
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []
